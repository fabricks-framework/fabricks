# %%
# %run ./add_missing_modules

# %%
from databricks.sdk.runtime import dbutils, spark

# %%
from fabricks.metastore.view import View

# %%
dbutils.widgets.text("schema_only", "false")
dbutils.widgets.text("arg1", "123")

# %%
schema_only = dbutils.widgets.get("schema_only").lower() == "true"
arg1 = dbutils.widgets.get("arg1")

# %%
assert arg1 == "1"

# %%
df = spark.sql(
    """
    select
      udf_key(array(f.id, d.time)) as __key,
      f.id as id,
      f.monarch as monarch,
      f.value as value,
      d.time as time
    from
      gold.dim_time d 
      cross join transf.fact_memory f
    where
      d.hour = 10
    """
)

# %%
uuid = View.create_or_replace(df)

# %%
if schema_only:
    dbutils.notebook.exit(uuid)

# %%
dbutils.notebook.exit(uuid)
