# %%
# %run ./add_missing_modules

# %%
from databricks.sdk.runtime import dbutils, spark

from fabricks.metastore.view import View

# %%
df_1 = spark.sql(
    """
    select 1 as `value`
    from gold.fact_overwrite
    limit 1
    """
)

# %%
df_2 = spark.sql(
    """
    select 2 as `value`
    from gold.fact_memory
    limit 1
    """
)

# %%
df_3 = spark.sql(
    """
    select 3 as `value`
    from gold.fact_option
    limit 1
    """
)

# %%
df = df_1.unionAll(df_2)  # .unionAll(df_3)

# %%
uuid = View.create_or_replace(df)

# %%
dbutils.notebook.exit(uuid)  # type: ignore
